# %% [markdown]
# Redes Neurais
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Neurônio:
#
# $$y = f(x_1 \cdot w_1 + x_2*w_2 + b)$$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Função de Ativação:
#
# * Sigmoid:
#
# $$\Theta(z) = \frac{1}{1 + e^{-z}}$$
#
# * ReLu:
#
# $$R(z) = max(0, z)$$

# %% [markdown]
# Treinamento:
#
# Processo semelhante ao treinamento de Regressão Linear
# * Definir função de perda
# * Otimizar com base na loss function de forma a reduzir as saída produzidas
#
# SGD (Stochastic Gradient Descent)
# * Momentum
# * Adam
